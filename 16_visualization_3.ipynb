# %%
#
# Template for Python program
# Name:
#

import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Input
y = np.array([35, 25, 25, 15])

# %%
# 3. Output
plt.title("Pie chart:Alex")
plt.pie(y)
plt.show()
