# %%
#
# Template for Python program
# Name:line
#

import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Input
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

# %% [markdown]
# No process

# %%
# 3. Output
plt.title("Line between two points: Alex")
plt.plot(xpoints, ypoints)
plt.show()
